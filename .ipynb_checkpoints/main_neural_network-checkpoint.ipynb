# %% [markdown]
# # Importing mnist dataset and normalising

# %%
import tensorflow

# %%
mnist = tensorflow.keras.datasets.mnist

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train= tensorflow.keras.utils.normalize(x_train, axis= 1)
x_test= tensorflow.keras.utils.normalize(x_test, axis= 1)

# %%
import matplotlib.pyplot as plt
plt.imshow(x_train[324], cmap = plt.cm.binary)
plt.show()

# %% [markdown]
# # Neural network

# %%
model = tensorflow.keras.models.Sequential()
model.add(tensorflow.keras.layers.Flatten())
model.add(tensorflow.keras.layers.Dense(128, activation= tensorflow.nn.relu))
model.add(tensorflow.keras.layers.Dense(128, activation= tensorflow.nn.relu))
model.add(tensorflow.keras.layers.Dense(10, activation= tensorflow.nn.softmax))
model.compile( optimizer= 'adam',
            loss='sparse_categorical_crossentropy',
             metrics = ['accuracy'])

# %%
model.fit(x_train, y_train, epochs = 5)
# Out:
# Train on 60000 samples
# Epoch 1/5
# WARNING:tensorflow:Entity <function Function._initialize_uninitialized_variables.<locals>.initialize_variables at 0x00000211BBCADB88> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: No module named 'tensorflow_core.estimator'
# WARNING: Entity <function Function._initialize_uninitialized_variables.<locals>.initialize_variables at 0x00000211BBCADB88> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: No module named 'tensorflow_core.estimator'
# 60000/60000 [==============================] - 6s 108us/sample - loss: 0.2620 - accuracy: 0.9234
# Epoch 2/5
# ...

# %%
validationLoss, validationAccuracy = model.evaluate(x_test, y_test)
# Out:
# 10000/1 [=============================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# ...

# %%
validationAccuracy
# Out:
# 0.972

# %%
validationLoss
# Out:
# 0.0999984571066685

# %%
import numpy

# %%
finalPredictions = model.predict([x_test])

# %%
finalPredictions = numpy.argmax(finalPredictions)

# %%
def realPicture(image_nparray, predictionvalues, printed):
    for i in range(len(image_nparray)): 
        ok = True
        for row in range(28):
            for col in range(28):
                if(image_nparray[i][row][col]):
                    ok = False
        if(ok == False):
            printed +=1
#             plt.imshow(image_nparray[i])
#             plt.show()
            print(f'----{1+i//9},{1+i%9}-------',numpy.argmax(predictionvalues[i]), '----------------')
    return printed

# %%
# from ipynb.fs.full.main_preprocessing import digits
# %store -r digits

# %%
sudokuPredictions = model.predict(digits)
print(sudokuPredictions.shape)
print(digits.shape)
# Out:
# (81, 10)
# (81, 28, 28)

# %%
digitsPresent = realPicture(digits, sudokuPredictions, 0)
# Out:
# ----1,1------- 3 ----------------
# ----1,2------- 3 ----------------
# ----1,3------- 5 ----------------
# ----1,4------- 5 ----------------
# ----1,5------- 2 ----------------
# ----1,6------- 2 ----------------
# ----1,7------- 5 ----------------
# ----1,8------- 3 ----------------
# ----1,9------- 3 ----------------
# ----2,1------- 8 ----------------
# ----2,2------- 3 ----------------
# ----2,3------- 5 ----------------
# ----2,4------- 3 ----------------
# ----2,5------- 3 ----------------
# ----2,6------- 9 ----------------
# ----2,7------- 2 ----------------
# ----2,8------- 5 ----------------
# ----2,9------- 2 ----------------
# ----3,1------- 2 ----------------
# ----3,2------- 5 ----------------
# ----3,3------- 2 ----------------
# ----3,4------- 3 ----------------
# ----3,5------- 8 ----------------
# ----3,6------- 5 ----------------
# ----3,7------- 3 ----------------
# ----3,8------- 5 ----------------
# ----3,9------- 3 ----------------
# ...

# %%
print(digitsPresent)
# Out:
# 0
